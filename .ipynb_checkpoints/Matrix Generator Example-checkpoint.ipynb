# %%
from MatrixGenerator import *

(C,D,M) = sampleMatrix(100, 20, 10, 4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-416a169fe1b1> in <module>()
#       1 from MatrixGenerator import *
#       2
# ----> 3 (C,D,M) = sampleMatrix(100, 20, 10, 4)
#
# ValueError: too many values to unpack (expected 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for i in range(nC):
    plt.pcolor(M[C[i],:])
    plt.show()
